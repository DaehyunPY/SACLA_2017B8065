# %%
import pickle
import os
import textwrap

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lmfit.models import GaussianModel

from dltools.cov.markup import compute

# %%
filename = "Data/Cov ang dist and KER at the low int group; target=C2p,I1p,I1p.pickle"

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

ykey = "n"
n = d["N"]
f = 1
print("{:.0f} ± {:.0f}".format(f * d["Cov[X,Y,Z]"][ykey].values * n,
                               f * d["Err[Cov[X,Y,Z]]"][ykey].values * n))

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

xkey, ykey = "ke", "sumke"
n = d["N"]
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.xlabel("KER")
plt.ylabel("Count")
plt.errorbar(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    d["Sum[XYZ]"][ykey][where] ** 0.5,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.errorbar(
    x[where],
    (d["Sum[XYZ]"][ykey] - d["Cov[X,Y,Z]"][ykey] * n)[where],
    ((d["Err[Cov[X,Y,Z]]"][ykey] * n) ** 2 - d["Sum[XYZ]"][ykey])[where] ** 0.5,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.grid(True)
plt.xlim(0, 150)
plt.tight_layout()
plt.show()

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

xkey, ykey = "p", "sumpx"
n = d["N"]
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.ylabel("Count")
plt.step(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    where="mid",
)
plt.step(
    x[where],
    (d["Sum[XYZ]"][ykey] - d["Cov[X,Y,Z]"][ykey] * n)[where],
    where="mid",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.grid(True)
plt.xlim(-200, 200)
plt.tight_layout()
plt.show()

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

xkey, ykey = "p", "sumpy"
n = d["N"]
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.ylabel("Count")
plt.step(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    where="mid",
)
plt.step(
    x[where],
    (d["Sum[XYZ]"][ykey] - d["Cov[X,Y,Z]"][ykey] * n)[where],
    where="mid",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.grid(True)
plt.xlim(-200, 200)
plt.tight_layout()
plt.show()

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

xkey, ykey = "p", "sumpz"
n = d["N"]
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.ylabel("Count")
plt.step(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    where="mid",
)
plt.step(
    x[where],
    (d["Sum[XYZ]"][ykey] - d["Cov[X,Y,Z]"][ykey] * n)[where],
    where="mid",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.grid(True)
plt.xlim(-200, 200)
plt.tight_layout()
plt.show()

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

xkey, ykey = "cosang", "h0h1angle"
n = d["N"]
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.xlabel("Angle btw h0 h1")
plt.ylabel("Count")
plt.step(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    where="mid",
)
plt.step(
    x[where],
    (d["Sum[XYZ]"][ykey] - d["Cov[X,Y,Z]"][ykey] * n)[where],
    where="mid",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.grid(True)
plt.xlim(-1, 1)
plt.tight_layout()
plt.show()

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

xkey, ykey = "cosang", "h0h2angle"
n = d["N"]
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.xlabel("Angle btw h0 h2")
plt.ylabel("Count")
plt.step(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    where="mid",
)
plt.step(
    x[where],
    (d["Sum[XYZ]"][ykey] - d["Cov[X,Y,Z]"][ykey] * n)[where],
    where="mid",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.grid(True)
plt.xlim(-1, 1)
plt.tight_layout()
plt.show()

# %%
with open(filename, "rb") as fp:
    d = pickle.load(fp)

xkey, ykey = "cosang", "h1h2angle"
n = d["N"]
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.xlabel("Angle btw h1 h2")
plt.ylabel("Count")
plt.step(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    where="mid",
)
plt.step(
    x[where],
    (d["Sum[XYZ]"][ykey] - d["Cov[X,Y,Z]"][ykey] * n)[where],
    where="mid",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.grid(True)
plt.xlim(-1, 1)
plt.tight_layout()
plt.show()
