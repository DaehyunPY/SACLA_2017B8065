# %%
import pickle
import os
import textwrap

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lmfit.models import GaussianModel

from dltools.cov.markup import compute

# %%
step = 0.002
edges = np.arange(0.005, 0.021, step)
filename = ("Data/Cov ang dist and KER; "
            "target=C1p,I2p,I1p "
            "& gm2={:.3f}--{:.3f}.pickle").format
note = textwrap.dedent("""\
    target = C1p,I2p,I1p
      flag <= 14
      -200 < p_(sum) < 200\
""")

# %%
def count():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            d = pickle.load(fp)

        key = "sumke"
        yield {"fr": fr,
               "n": d["N"],
               "cov": d["Cov[X,Y,Z]"][key].sum().values}


df = pd.DataFrame(list(count()))

plt.figure()
plt.xlabel("Intensity")
plt.ylabel("Cov yield")
plt.plot(df["fr"] + step / 2, df["cov"], "-o")
plt.grid(True)
v, _ = plt.ylim()
plt.ylim(min(v, 0), None)

plt.twinx()
plt.ylabel("Count")
plt.step(df["fr"] + step / 2, df["n"], where="mid")
plt.ylim(0, None)
plt.tight_layout()
plt.show()

# %%
from textwrap import dedent
import os
import pickle

import matplotlib.pyplot as plt
import numpy as np


step = 0.002
edges = np.arange(0.005, 0.021, step)
filename = ("Data/Cov ang dist and KER; "
            "target=C1p,I2p,I1p "
            "& gm2={:.3f}--{:.3f}.pickle").format
note = dedent("""\
    target = C1p,I2p,I1p
      flag <= 14
      -200 < p_(sum) < 200\
""")


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            yield {"i": i,
                   "d": pickle.load(fp),
                   "fr": fr,
                   "to": to}


rows = list(gen())
xkey, ykey = "ke", "sumke"

plt.figure(figsize=(9, 12))
plt.subplot(4, 3, 1)
plt.xlabel("KER")
plt.ylabel("Mean cov yield")
n = sum(r["d"]["N"] for r in rows)
d = {
    "Cov[X,Y,Z]": sum(r["d"]["N"] * r["d"]["Cov[X,Y,Z]"] for r in rows) / n,
    "Err[Cov[X,Y,Z]]": sum((r["d"]["N"] * r["d"]["Err[Cov[X,Y,Z]]"]) ** 2 for r in rows) ** 0.5 / n,
    "Sum[XYZ]": sum(r["d"]["Sum[XYZ]"] for r in rows),
}
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
where = 1 < d["Sum[XYZ]"][ykey]
plt.errorbar(
    d["Cov[X,Y,Z]"][xkey][where] + dx / 2,
    d["Cov[X,Y,Z]"][ykey][where],
    d["Err[Cov[X,Y,Z]]"][ykey][where],
    fmt=" ",
    capsize=2,
)
plt.grid(True)
plt.xlim(0, 150)
plt.ylim(-0.0004, 0.0012)
plt.gca().label_outer()


def gen():
    for r in rows:
        n = r["d"]["N"]
        dx = r["d"]["Cov[X,Y,Z]"][xkey][1] - r["d"]["Cov[X,Y,Z]"][xkey][0]
        where = 0 < r["d"]["Sum[XYZ]"][ykey]
        if where.sum() == 0:
            continue

        ave = np.average(
            r["d"]["Cov[X,Y,Z]"][xkey][where] + dx / 2,
            weights=r["d"]["Cov[X,Y,Z]"][ykey][where],
        )
        std = np.average(
            (r["d"]["Cov[X,Y,Z]"][xkey][where] + dx / 2 - ave) ** 2,
            weights=r["d"]["Cov[X,Y,Z]"][ykey][where],
        ) ** 0.5
        yield {"x": ave, "xerr": std, "y": (r["fr"] + r["to"]) / 2}


plt.subplot(4, 3, 2)
plt.xlabel("KER")
plt.ylabel("GM2")
df = pd.DataFrame(list(gen()))
plt.errorbar(
    df["x"], df["y"],
    xerr=df["xerr"],
    fmt=".",
    capsize=2,
)
plt.xlim(0, 150)
plt.grid(True)
plt.gca().label_outer()


def gen():
    for r in rows:
        y = r["d"]["Cov[X,Y,Z]"][ykey].sum().values
        yerr = ((r["d"]["Err[Cov[X,Y,Z]]"][ykey] ** 2).sum() ** 0.5).values
        if y < 0:
            continue
        yield {"x": (r["fr"] + r["to"]) / 2,
               "n": r["d"]["N"],
               "y": y,
               "yerr": yerr}


plt.subplot(4, 3, 3)
df = pd.DataFrame(list(gen()))
plt.step(
    df["x"], df["n"],
    where="mid",
    color="gray",
)
plt.ylim(0, None)
plt.minorticks_on()
plt.grid(True, which="both")
plt.yticks([], [])

plt.twinx()
plt.ylabel("Cov yield")
plt.errorbar(
    df["x"], df["y"], df["yerr"],
    fmt=".",
    capsize=2,
)
plt.minorticks_on()
plt.grid(True, which="both")
plt.xscale("log")
plt.yscale("log")


for r in rows:
    n = r["d"]["N"]
    dx = r["d"]["Cov[X,Y,Z]"][xkey][1] - r["d"]["Cov[X,Y,Z]"][xkey][0]
    where = r["d"]["Sum[XYZ]"][ykey] != 0

    plt.subplot(4, 3, r["i"] + 4)
    plt.title(f"GM2: {r['fr']:.3f}--{r['to']:.3f}\n"
              f"  N: {n}",
              fontdict={"family": "monospace", "size": "medium"},
              loc="left")
    plt.xlabel("KER")
    plt.ylabel("Cov yield")
    plt.errorbar(
        r["d"]["Cov[X,Y,Z]"][xkey][where] + dx / 2,
        r["d"]["Cov[X,Y,Z]"][ykey][where],
        r["d"]["Err[Cov[X,Y,Z]]"][ykey][where],
        fmt=",",
        capsize=2,
    )
    plt.grid(True)
    plt.xlim(0, 150)
    plt.ylim(-0.0004, 0.0012)
    plt.gca().label_outer()
plt.subplot(4, 3, 12)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
## x, y = "ke", "sumke"

plt.figure(figsize=(9, 12))


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            yield pickle.load(fp)
            

li = list(load())
n = sum(d["N"] for d in li)
d = {
    "Cov[X,Y,Z]": sum(d["N"] * d["Cov[X,Y,Z]"] for d in li) / n,
    "Err[Cov[X,Y,Z]]": sum((d["N"] * d["Err[Cov[X,Y,Z]]"]) ** 2 for d in li) ** 0.5 / n,
    "Sum[XYZ]": sum(d["Sum[XYZ]"] for d in li),
}
dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
where = 1 < d["Sum[XYZ]"][y]

plt.subplot(4, 3, 1)
plt.xlabel("KER")
plt.ylabel("Mean cov yield")
plt.errorbar(
    d["Cov[X,Y,Z]"][x][where] + dx / 2,
    d["Cov[X,Y,Z]"][y][where],
    d["Err[Cov[X,Y,Z]]"][y][where],
    fmt=" ",
    capsize=2,
)
plt.grid(True)
plt.xlim(0, 150)
plt.ylim(-0.0004, 0.0012)
plt.gca().label_outer()


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            d = pickle.load(fp)
        n = d["N"]
        dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
        where = 0 < d["Sum[XYZ]"][y]
        if where.sum() == 0:
            continue

        ave = np.average(
            d["Cov[X,Y,Z]"][x][where] + dx / 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        )
        std = np.average(
            (d["Cov[X,Y,Z]"][x][where] + dx / 2 - ave) ** 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        ) ** 0.5
        yield {"x": ave, "xerr": std, "y": (fr + to) / 2}


plt.subplot(4, 3, 2)
plt.xlabel("KER")
plt.ylabel("GM2")
df = pd.DataFrame(list(gen()))
plt.errorbar(
    df["x"], df["y"],
    xerr=df["xerr"],
    fmt=".",
    capsize=2,
)
plt.xlim(0, 150)
plt.grid(True)
plt.gca().label_outer()


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            d = pickle.load(fp)

        yield {"x": (fr + to) / 2,
               "n": d["N"],
               "y": d["Cov[X,Y,Z]"][y].sum().values,
               "yerr": ((d["Err[Cov[X,Y,Z]]"][y] ** 2).sum() ** 0.5).values}


df = pd.DataFrame(list(gen()))

plt.subplot(4, 3, 3)
plt.xlabel("GM2")
plt.ylabel("Cov yield")
plt.errorbar(
    df["x"], df["y"], df["yerr"],
    fmt=".",
    capsize=2,
)
plt.minorticks_on()
plt.grid(True, which="both")
# v, _ = plt.ylim()
# plt.ylim(min(v, 0), None)
# plt.yticks([0], [0])
plt.xscale("log")
plt.yscale("log")

plt.twinx()
# plt.ylabel("Count")
plt.step(df["x"], df["n"], where="mid", color="gray")
plt.ylim(0, None)
plt.yticks([0], [0])
# plt.gca().label_outer()


for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]
    dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
    where = d["Sum[XYZ]"][y] != 0

    plt.subplot(4, 3, i + 4)
    plt.title(f"GM2: {fr:.3f}--{to:.3f}\n"
              f"  N: {n}",
              fontdict={"family": "monospace", "size": "medium"},
              loc="left")
    plt.xlabel("KER")
    plt.ylabel("Cov yield")
    plt.errorbar(
        d["Cov[X,Y,Z]"][x][where] + dx / 2,
        d["Cov[X,Y,Z]"][y][where],
        d["Err[Cov[X,Y,Z]]"][y][where],
        fmt=",",
        capsize=2,
    )
    plt.grid(True)
    plt.xlim(0, 150)
    plt.ylim(-0.0004, 0.0012)
    plt.gca().label_outer()
plt.subplot(4, 3, 12)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "ke", "sumke"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Cov[X,Y,Z]"])
    plt.step(
        arr[x], arr[y] * n,
        label="Cov[X,Y,Z] * N",
        where="post",
    )
    arr = compute(d["Sum[XYZ]"])
    plt.step(
        arr[x], arr[y],
        label="Sum[XYZ]",
        where="post",
    )
    arr = compute(d["Sum[XY]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XY]Sum[Z] / N",
        where="post",
    )
    arr = compute(d["Sum[XZ]Sum[Y]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XZ]Sum[Y] / N",
        where="post",
    )
    arr = compute(d["Sum[YZ]Sum[X]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[YZ]Sum[X] / N",
        where="post",
    )
    arr = compute(d["Sum[X]Sum[Y]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n ** 2,
        label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
        where="post",
    )
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "p", "sumpz"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Cov[X,Y,Z]"])
    plt.step(
        arr[x], arr[y] * n,
        label="Cov[X,Y,Z] * N",
        where="post",
    )
    arr = compute(d["Sum[XYZ]"])
    plt.step(
        arr[x], arr[y],
        label="Sum[XYZ]",
        where="post",
    )
    arr = compute(d["Sum[XY]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XY]Sum[Z] / N",
        where="post",
    )
    arr = compute(d["Sum[XZ]Sum[Y]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XZ]Sum[Y] / N",
        where="post",
    )
    arr = compute(d["Sum[YZ]Sum[X]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[YZ]Sum[X] / N",
        where="post",
    )
    arr = compute(d["Sum[X]Sum[Y]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n ** 2,
        label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
        where="post",
    )
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "p", "sumpx"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Cov[X,Y,Z]"])
    plt.step(
        arr[x], arr[y] * n,
        label="Cov[X,Y,Z] * N",
        where="post",
    )
    arr = compute(d["Sum[XYZ]"])
    plt.step(
        arr[x], arr[y],
        label="Sum[XYZ]",
        where="post",
    )
    arr = compute(d["Sum[XY]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XY]Sum[Z] / N",
        where="post",
    )
    arr = compute(d["Sum[XZ]Sum[Y]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XZ]Sum[Y] / N",
        where="post",
    )
    arr = compute(d["Sum[YZ]Sum[X]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[YZ]Sum[X] / N",
        where="post",
    )
    arr = compute(d["Sum[X]Sum[Y]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n ** 2,
        label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
        where="post",
    )
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "p", "sumpy"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Cov[X,Y,Z]"])
    plt.step(
        arr[x], arr[y] * n,
        label="Cov[X,Y,Z] * N",
        where="post",
    )
    arr = compute(d["Sum[XYZ]"])
    plt.step(
        arr[x], arr[y],
        label="Sum[XYZ]",
        where="post",
    )
    arr = compute(d["Sum[XY]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XY]Sum[Z] / N",
        where="post",
    )
    arr = compute(d["Sum[XZ]Sum[Y]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XZ]Sum[Y] / N",
        where="post",
    )
    arr = compute(d["Sum[YZ]Sum[X]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[YZ]Sum[X] / N",
        where="post",
    )
    arr = compute(d["Sum[X]Sum[Y]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n ** 2,
        label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
        where="post",
    )
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "ke", "sumke"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]
    dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
    where = d["Sum[XYZ]"][y] != 0

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    plt.errorbar(
        d["Cov[X,Y,Z]"][x][where] + dx / 2,
        d["Cov[X,Y,Z]"][y][where],
        d["Sum[XYZ]"][y][where] ** 0.5 / n,
        fmt=",",
        capsize=2,
    )
    plt.grid(True)
    plt.xlim(0, 100)
    plt.ylim(-0.0002, 0.0012)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "ke", "sumke"


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            d = pickle.load(fp)
        n = d["N"]
        dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
        where = 0 < d["Sum[XYZ]"][y]
        if where.sum() == 0:
            continue

        ave = np.average(
            d["Cov[X,Y,Z]"][x][where] + dx / 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        )
        std = np.average(
            (d["Cov[X,Y,Z]"][x][where] + dx / 2 - ave) ** 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        ) ** 0.5
        yield {"x": (fr + to) / 2, "y": ave, "yerr": std}
        
    
df = pd.DataFrame(list(gen()))
plt.errorbar(
    df["x"], df["y"], df["yerr"],
    fmt=".",
    capsize=2,
)
plt.grid(True)
plt.ylim(0, 100)
plt.show()

# %%
x, y = "cosang", "h0h1angle"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Cov[X,Y,Z]"])
    plt.step(
        arr[x], arr[y] * n,
        label="Cov[X,Y,Z] * N",
        where="post",
    )
    arr = compute(d["Sum[XYZ]"])
    plt.step(
        arr[x], arr[y],
        label="Sum[XYZ]",
        where="post",
    )
    arr = compute(d["Sum[XY]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XY]Sum[Z] / N",
        where="post",
    )
    arr = compute(d["Sum[XZ]Sum[Y]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XZ]Sum[Y] / N",
        where="post",
    )
    arr = compute(d["Sum[YZ]Sum[X]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[YZ]Sum[X] / N",
        where="post",
    )
    arr = compute(d["Sum[X]Sum[Y]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n ** 2,
        label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
        where="post",
    )
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "cosang", "h0h1angle"


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            d = pickle.load(fp)
        n = d["N"]
        dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
        where = 0 < d["Sum[XYZ]"][y]
        if where.sum() == 0:
            continue

        ave = np.average(
            d["Cov[X,Y,Z]"][x][where] + dx / 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        )
        std = np.average(
            (d["Cov[X,Y,Z]"][x][where] + dx / 2 - ave) ** 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        ) ** 0.5
        if np.isfinite(std):
            yield {"x": (fr + to) / 2, "y": ave, "yerr": std}
        
    
df = pd.DataFrame(list(gen()))
# df
plt.figure()
plt.errorbar(
    df["x"], df["y"], df["yerr"],
    fmt=".",
    capsize=2,
)
plt.ylim(-1, 1)
plt.grid(True)
plt.show()
# Out:
# /opt/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars
# /opt/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars

# %%
x, y = "cosang", "h0h2angle"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Cov[X,Y,Z]"])
    plt.step(
        arr[x], arr[y] * n,
        label="Cov[X,Y,Z] * N",
        where="post",
    )
    arr = compute(d["Sum[XYZ]"])
    plt.step(
        arr[x], arr[y],
        label="Sum[XYZ]",
        where="post",
    )
    arr = compute(d["Sum[XY]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XY]Sum[Z] / N",
        where="post",
    )
    arr = compute(d["Sum[XZ]Sum[Y]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XZ]Sum[Y] / N",
        where="post",
    )
    arr = compute(d["Sum[YZ]Sum[X]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[YZ]Sum[X] / N",
        where="post",
    )
    arr = compute(d["Sum[X]Sum[Y]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n ** 2,
        label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
        where="post",
    )
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "cosang", "h0h2angle"


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            d = pickle.load(fp)
        n = d["N"]
        dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
        where = 0 < d["Sum[XYZ]"][y]
        if where.sum() == 0:
            continue

        ave = np.average(
            d["Cov[X,Y,Z]"][x][where] + dx / 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        )
        std = np.average(
            (d["Cov[X,Y,Z]"][x][where] + dx / 2 - ave) ** 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        ) ** 0.5
        if np.isfinite(std):
            yield {"x": (fr + to) / 2, "y": ave, "yerr": std}
        
    
df = pd.DataFrame(list(gen()))
# df
plt.figure()
plt.errorbar(
    df["x"], df["y"], df["yerr"],
    fmt=".",
    capsize=2,
)
plt.ylim(-1, 1)
plt.grid(True)
plt.show()
# Out:
# /opt/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars
# /opt/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars

# %%
x, y = "cosang", "h1h2angle"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Cov[X,Y,Z]"])
    plt.step(
        arr[x], arr[y] * n,
        label="Cov[X,Y,Z] * N",
        where="post",
    )
    arr = compute(d["Sum[XYZ]"])
    plt.step(
        arr[x], arr[y],
        label="Sum[XYZ]",
        where="post",
    )
    arr = compute(d["Sum[XY]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XY]Sum[Z] / N",
        where="post",
    )
    arr = compute(d["Sum[XZ]Sum[Y]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[XZ]Sum[Y] / N",
        where="post",
    )
    arr = compute(d["Sum[YZ]Sum[X]"])
    plt.step(
        arr[x], arr[y] / n,
        label="Sum[YZ]Sum[X] / N",
        where="post",
    )
    arr = compute(d["Sum[X]Sum[Y]Sum[Z]"])
    plt.step(
        arr[x], arr[y] / n ** 2,
        label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
        where="post",
    )
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y = "cosang", "h1h2angle"


def gen():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            d = pickle.load(fp)
        n = d["N"]
        dx = d["Cov[X,Y,Z]"][x][1] - d["Cov[X,Y,Z]"][x][0]
        where = 0 < d["Sum[XYZ]"][y]
        if where.sum() == 0:
            continue

        ave = np.average(
            d["Cov[X,Y,Z]"][x][where] + dx / 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        )
        std = np.average(
            (d["Cov[X,Y,Z]"][x][where] + dx / 2 - ave) ** 2,
            weights=d["Cov[X,Y,Z]"][y][where],
        ) ** 0.5
        if np.isfinite(std):
            yield {"x": (fr + to) / 2, "y": ave, "yerr": std}
        
    
df = pd.DataFrame(list(gen()))
# df
plt.figure()
plt.errorbar(
    df["x"], df["y"], df["yerr"],
    fmt=".",
    capsize=2,
)
plt.ylim(-1, 1)
plt.grid(True)
plt.show()
# Out:
# /opt/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars
# /opt/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars

# %%
def load():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            yield pickle.load(fp)


li = list(load())
n = sum(d["N"] for d in li)
d = {
    "Cov[X,Y,Z]": sum(d["N"] * d["Cov[X,Y,Z]"] for d in li) / n,
    "Err[Cov[X,Y,Z]]": sum((d["N"] * d["Err[Cov[X,Y,Z]]"]) ** 2 for d in li) ** 0.5 / n,
    "Sum[XYZ]": sum(d["Sum[XYZ]"] for d in li),
}
xkey, ykey = "ke", "sumke"
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
y = d["Cov[X,Y,Z]"][ykey]
where = 0 < d["Sum[XYZ]"][ykey]

ave = np.average(x[where], weights=y[where])
std = np.average((x[where] - ave) ** 2, weights=y[where]) ** 0.5

plt.figure()
plt.xlabel("KER")
plt.ylabel("Count")
plt.errorbar(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    d["Sum[XYZ]"][ykey][where] ** 0.5,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.axvline(24, color="green")
plt.axvline(ave, color="grey")
plt.axvspan(ave - std, ave + std, alpha=0.2, color="grey")
plt.minorticks_on()
plt.grid(True, which="both")
plt.xlim(0, 150)
plt.tight_layout()
plt.show()

print(ave, std)
# Out:
# 28.102706228144374 6.976644452949971

# %%
def load():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            yield pickle.load(fp)


li = list(load())
n = sum(d["N"] for d in li)
d = {
    "Cov[X,Y,Z]": sum(d["N"] * d["Cov[X,Y,Z]"] for d in li) / n,
    "Err[Cov[X,Y,Z]]": sum((d["N"] * d["Err[Cov[X,Y,Z]]"]) ** 2 for d in li) ** 0.5 / n,
    "Sum[XYZ]": sum(d["Sum[XYZ]"] for d in li),
}
xkey, ykey = "cosang", "h0h1angle"
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.xlabel("Angle (cos)")
plt.ylabel("Count")
plt.errorbar(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    d["Sum[XYZ]"][ykey][where] ** 0.5,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
model = GaussianModel()
fitted = model.fit(
    d["Cov[X,Y,Z]"][ykey][where],
    weights=d["Err[Cov[X,Y,Z]]"][ykey][where],
    x=x[where])
plt.plot(x, fitted.eval(x=x) * n)
plt.grid(True)
plt.tight_layout()
plt.show()

fitted
# Out:
# <h2> Model</h2> Model(gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>64</td><td></td></tr><tr><td># data points</td><td>100</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 1.5755e-17</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.6242e-19</td><td></td></tr><tr><td>Akaike info crit.</td><td>-4323.45635</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-4315.64084</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> sigma </td><td>  0.18364335 </td><td>  0.00494498 </td><td> 2.69% </td><td> 1.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> center </td><td> -0.31716588 </td><td>  0.00451915 </td><td> -1.42% </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> amplitude </td><td>  1.2385e-04 </td><td>  2.7874e-06 </td><td> 2.25% </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> fwhm </td><td>  0.43244703 </td><td>  0.01164454 </td><td> 2.69% </td><td> 2.35482 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 2.3548200*sigma </td></tr><tr><td> height </td><td>  2.6906e-04 </td><td>  4.9399e-06 </td><td> 1.84% </td><td> 0.3989423 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 0.3989423*amplitude/max(1.e-15, sigma) </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sigma</td><td>amplitude</td><td>0.7380</td></tr><tr><td>center</td><td>amplitude</td><td>0.1380</td></tr><tr><td>sigma</td><td>center</td><td>0.1329</td></tr></table>

# %%
def load():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            yield pickle.load(fp)


li = list(load())
n = sum(d["N"] for d in li)
d = {
    "Cov[X,Y,Z]": sum(d["N"] * d["Cov[X,Y,Z]"] for d in li) / n,
    "Err[Cov[X,Y,Z]]": sum((d["N"] * d["Err[Cov[X,Y,Z]]"]) ** 2 for d in li) ** 0.5 / n,
    "Sum[XYZ]": sum(d["Sum[XYZ]"] for d in li),
}
xkey, ykey = "cosang", "h0h2angle"
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.xlabel("Angle (cos)")
plt.ylabel("Count")
plt.errorbar(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    d["Sum[XYZ]"][ykey][where] ** 0.5,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
model = GaussianModel()
fitted = model.fit(
    d["Cov[X,Y,Z]"][ykey][where],
    weights=d["Err[Cov[X,Y,Z]]"][ykey][where],
    x=x[where])
plt.plot(x, fitted.eval(x=x) * n)
plt.grid(True)
plt.tight_layout()
plt.show()

fitted
# Out:
# <h2> Model</h2> Model(gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>213</td><td></td></tr><tr><td># data points</td><td>100</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 1.0173e-17</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.0488e-19</td><td></td></tr><tr><td>Akaike info crit.</td><td>-4367.19359</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-4359.37808</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> sigma </td><td>  0.17292730 </td><td>  0.00347101 </td><td> 2.01% </td><td> 1.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> center </td><td> -0.28112283 </td><td>  0.00310800 </td><td> -1.11% </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> amplitude </td><td>  1.2752e-04 </td><td>  2.1212e-06 </td><td> 1.66% </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> fwhm </td><td>  0.40721267 </td><td>  0.00817360 </td><td> 2.01% </td><td> 2.35482 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 2.3548200*sigma </td></tr><tr><td> height </td><td>  2.9418e-04 </td><td>  3.9935e-06 </td><td> 1.36% </td><td> 0.3989423 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 0.3989423*amplitude/max(1.e-15, sigma) </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sigma</td><td>amplitude</td><td>0.7417</td></tr></table>

# %%
def load():
    for i, fr in enumerate(edges):
        to = fr + step
        fn = filename(fr, to)
        if not os.path.exists(fn):
            continue

        with open(fn, "rb") as fp:
            yield pickle.load(fp)


li = list(load())
n = sum(d["N"] for d in li)
d = {
    "Cov[X,Y,Z]": sum(d["N"] * d["Cov[X,Y,Z]"] for d in li) / n,
    "Err[Cov[X,Y,Z]]": sum((d["N"] * d["Err[Cov[X,Y,Z]]"]) ** 2 for d in li) ** 0.5 / n,
    "Sum[XYZ]": sum(d["Sum[XYZ]"] for d in li),
}
xkey, ykey = "cosang", "h1h2angle"
dx = d["Cov[X,Y,Z]"][xkey][1] - d["Cov[X,Y,Z]"][xkey][0]
x = d["Cov[X,Y,Z]"][xkey] + dx / 2
where = 0 < d["Sum[XYZ]"][ykey]

plt.figure()
plt.xlabel("Angle (cos)")
plt.ylabel("Count")
plt.errorbar(
    x[where],
    d["Sum[XYZ]"][ykey][where],
    d["Sum[XYZ]"][ykey][where] ** 0.5,
    fmt=" ",
    capsize=2,
    label="Cov",
)
plt.errorbar(
    x[where],
    d["Cov[X,Y,Z]"][ykey][where] * n,
    d["Err[Cov[X,Y,Z]]"][ykey][where] * n,
    fmt=" ",
    capsize=2,
    label="Cov",
)
model = GaussianModel()
fitted = model.fit(
    d["Cov[X,Y,Z]"][ykey][where],
    weights=d["Err[Cov[X,Y,Z]]"][ykey][where],
    x=x[where])
plt.plot(x, fitted.eval(x=x) * n)
plt.grid(True)
plt.tight_layout()
plt.show()

fitted
# Out:
# <h2> Model</h2> Model(gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>74</td><td></td></tr><tr><td># data points</td><td>100</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 3.2197e-17</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.3193e-19</td><td></td></tr><tr><td>Akaike info crit.</td><td>-4251.98235</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-4244.16684</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> sigma </td><td>  0.10999857 </td><td>  0.00239995 </td><td> 2.18% </td><td> 1.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> center </td><td> -0.78406219 </td><td>  0.00215892 </td><td> -0.28% </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> amplitude </td><td>  1.2039e-04 </td><td>  2.1748e-06 </td><td> 1.81% </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> fwhm </td><td>  0.25902683 </td><td>  0.00565144 </td><td> 2.18% </td><td> 2.35482 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 2.3548200*sigma </td></tr><tr><td> height </td><td>  4.3663e-04 </td><td>  6.6967e-06 </td><td> 1.53% </td><td> 0.3989423 </td><td>        -inf </td><td>         inf </td><td> False </td><td> 0.3989423*amplitude/max(1.e-15, sigma) </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sigma</td><td>amplitude</td><td>0.7195</td></tr><tr><td>center</td><td>amplitude</td><td>0.2519</td></tr><tr><td>sigma</td><td>center</td><td>0.1851</td></tr></table>

# %%
x, y, c0, c1 = "normp0", "normp1", "h1normpxy", "h2normpxy"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
#     arr = compute(d["Sum[XYZ]"])
    arr = compute(d["Cov[X,Y,Z]"])
    dx = arr[x][1] - arr[x][0]
    dy = arr[y][1] - arr[y][0]
    plt.pcolormesh(
        arr[x] + dx / 2,
        arr[y] + dy / 2,
        (arr[c0] + arr[c1]).T,
        cmap="RdBu",
        label="Cov[X,Y,Z]",
    )
    plt.clim(-0.0001, 0.0001)
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
x, y, c0, c1 = "normp0", "normp1", "h1normpxy", "h2normpxy"

plt.figure(figsize=(9, 9))
for i, fr in enumerate(edges):
    to = fr + step
    fn = filename(fr, to)
    if not os.path.exists(fn):
        continue

    with open(fn, "rb") as fp:
        d = pickle.load(fp)
    n = d["N"]

    plt.subplot(3, 3, i + 1)
    plt.title(f"gm2: {fr:.3f}--{to:.3f}\nn: {n}")
    arr = compute(d["Sum[XYZ]"])
    dx = arr[x][1] - arr[x][0]
    dy = arr[y][1] - arr[y][0]
    plt.pcolormesh(
        arr[x] + dx / 2,
        arr[y] + dy / 2,
        (arr[c0] + arr[c1]).T / n,
        cmap="RdBu",
        label="Sum[XYZ] / N",
    )
    plt.clim(-0.0001, 0.0001)
    plt.grid(True)
plt.subplot(339)
plt.text(0, 1, note,
         fontdict={"family": "monospace"},
         verticalalignment="top")
plt.axis("off")
plt.tight_layout()
plt.show()
