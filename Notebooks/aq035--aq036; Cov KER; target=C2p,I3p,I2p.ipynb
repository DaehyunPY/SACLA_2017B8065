# %%
# %% Import packages
from pprint import pprint
from itertools import chain, compress, product
from functools import reduce, partial, lru_cache
from glob import iglob
from typing import Generator

from numba import jit
from yaml import safe_load
from cytoolz import compose, merge_with
import numpy as np
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession, Row, DataFrame, functions as f
from dltools import load_combiner
from dltools.sacla import restructure, load_analyzer

# %%
# %% Load PySpark
builder = (
    SparkSession
    .builder
    .config("spark.executor.memory", "16g")
    .config("spark.driver.memory", "16g")
    .config("spark.driver.maxResultSize", "4g")
    .config(        
        "spark.jars.packages",
        "org.apache.hadoop:hadoop-aws:2.7.0,"
        "org.mongodb.spark:mongo-spark-connector_2.11:2.3.1,"
        "org.diana-hep:spark-root_2.11:0.1.15,"
    )
)

print("Loading PySpark...")
spark = builder.getOrCreate()
print("Done!")
# Out:
# Loading PySpark...
# Done!

# %%
# %% Load data
from pyspark.sql.types import (
    ArrayType, BooleanType, LongType, StructField, StructType, DoubleType,
)
from dltools import SpkHits


print("Loading data...")
df = (
    spark
    .read
    .format("com.mongodb.spark.sql.DefaultSource")
    .option("uri", "mongodb://mongodb/sacla_2017b8065.resorted")
    .option("pipeline", """[
        {
            $match: {
                aq: {$in: [35, 36]},
            },
        },
        {
            $project: {
                tag: true,
                hits: {
                    $filter: {
                        input: "$hits",
                        as: "item",
                        cond: {$lte: ["$$item.flag", 6]},
                    },
                },
            },
        },
    ]""")
    .schema(
        StructType([
            StructField("tag", LongType()),
            StructField("hits", SpkHits)
        ])
    )
    .load()
)
df.printSchema()
print("Done!")
# Out:
# Loading data...
# root
#  |-- tag: long (nullable = true)
#  |-- hits: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- t: double (nullable = false)
#  |    |    |-- x: double (nullable = false)
#  |    |    |-- y: double (nullable = false)
#  |    |    |-- as_: map (nullable = false)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: struct (valueContainsNull = true)
#  |    |    |    |    |-- pz: double (nullable = false)
#  |    |    |    |    |-- px: double (nullable = false)
#  |    |    |    |    |-- py: double (nullable = false)
#  |    |    |    |    |-- ke: double (nullable = false)
#  |    |    |-- flag: integer (nullable = true)
#
# Done!

# %%
import typing
import pyspark
from cov import cov3d_complicated


def ishit0(hit: pyspark.sql.Row) -> bool:
    return "C2p" in hit["as_"]


def ishit1(hit: pyspark.sql.Row) -> bool:
    return "I3p" in hit["as_"]


def ishit2(hit: pyspark.sql.Row) -> bool:
    return "I2p" in hit["as_"]


combined = cov3d_complicated(
    df, ishit0, ishit1, ishit2,
    npart=60,
    opt1={
        "npart": 12,
    },
    opt2={
        "fraction": 0.1,
        "npart": 60,
    },
    opt3={
        "fraction": 0.01,
        "npart": 60,
    },
)

# %%
def hist_ker(rows: typing.List[pyspark.sql.Row]) -> typing.List[np.ndarray]:
    ret, *_ = np.histogram(
        [
            r["hit0"]["as_"]["C2p"]["ke"]
            + r["hit1"]["as_"]["I3p"]["ke"]
            + r["hit2"]["as_"]["I2p"]["ke"]
            for r in rows
        ],
        bins=np.linspace(0, 200, 51),
    )
    return [ret]

# %%
# combined(hist_ker)
x = np.linspace(0, 200, 51)[1:]
n = combined(hist_ker)["N"]

plt.figure(figsize=(6, 6))
plt.step(
    x, combined(hist_ker)["Cov[X,Y,Z]"] * n,
    label="Cov[X,Y,Z] * N",
)
plt.step(
    x, combined(hist_ker)["Sum[XYZ]"],
    label="Sum[XYZ]",
)
# plt.step(
#     x, combined(hist_ker)["Sum[XY]Sum[Z]"] / n,
#     label="Sum[XY]Sum[Z] / N",
# )
# plt.step(
#     x, combined(hist_ker)["Sum[XZ]Sum[Y]"] / n,
#     label="Sum[XZ]Sum[Y] / N",
# )
# plt.step(
#     x, combined(hist_ker)["Sum[YZ]Sum[X]"] / n,
#     label="Sum[YZ]Sum[X] / N",
# )
# plt.step(
#     x, combined(hist_ker)["Sum[X]Sum[Y]Sum[Z]"] / n ** 2,
#     label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
# )

# plt.xlim(0, 60)
# plt.ylim(0, None)
plt.minorticks_on()
plt.grid(True, which="both")
plt.legend(shadow=True)

plt.tight_layout()
# plt.savefig("Figures/aq035--aq036; Covariant KER; C2p,I3p,I2p.pdf")
plt.show()

# %%
def hist_pyz(rows: typing.List[pyspark.sql.Row]) -> typing.List[np.ndarray]:
    data = np.array([
        [r["hit0"]["as_"]["C2p"]["py"]
         + r["hit1"]["as_"]["I3p"]["py"]
         + r["hit2"]["as_"]["I2p"]["py"],
         r["hit0"]["as_"]["C2p"]["pz"]
         + r["hit1"]["as_"]["I3p"]["pz"]
         + r["hit2"]["as_"]["I2p"]["pz"]]
        for r in rows
    ]).reshape(-1, 2)
    ret, *_ = np.histogram2d(
        data[:, 0],
        data[:, 1],
        bins=(
            np.linspace(-200, 200, 101),
            np.linspace(-200, 200, 101),
        ),
    )
    return [ret]

# %%
x = np.linspace(-200, 200, 101)[1:]
n = combined(hist_pyz)["N"]

plt.figure(figsize=(6, 6))
plt.subplot(211)
plt.text(1, 1, "Total momentum of y-axis",
         horizontalalignment="right",
         verticalalignment="top",
         transform=plt.gca().transAxes,
         bbox={"facecolor": "w", "edgecolor": "w"})
ax = 1
plt.step(
    x, combined(hist_pyz)["Cov[X,Y,Z]"].sum(ax) * n,
    label="Cov[X,Y,Z] * N",
)
plt.step(
    x, combined(hist_pyz)["Sum[XYZ]"].sum(ax),
    label="Sum[XYZ]",
)
# plt.step(
#     x, combined(hist_pyz)["Sum[XY]Sum[Z]"].sum(ax) / n,
#     label="Sum[XY]Sum[Z] / N",
# )
# plt.step(
#     x, combined(hist_pyz)["Sum[XZ]Sum[Y]"].sum(ax) / n,
#     label="Sum[XZ]Sum[Y] / N",
# )
# plt.step(
#     x, combined(hist_pyz)["Sum[YZ]Sum[X]"].sum(ax) / n,
#     label="Sum[YZ]Sum[X] / N",
# )
# plt.step(
#     x, combined(hist_pyz)["Sum[X]Sum[Y]Sum[Z]"].sum(ax) / n ** 2,
#     label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
# )
plt.axhline(0, color="k")
plt.minorticks_on()
plt.grid(True, which="both")
# plt.legend(loc="upper left", shadow=True)
plt.gca().label_outer()

plt.subplot(212)
plt.text(1, 1, "Total momentum of z-axis",
         horizontalalignment="right",
         verticalalignment="top",
         transform=plt.gca().transAxes,
         bbox={"facecolor": "w", "edgecolor": "w"})
ax = 0
plt.step(
    x, combined(hist_pyz)["Cov[X,Y,Z]"].sum(ax) * n,
    label="Cov[X,Y,Z] * N",
)
plt.step(
    x, combined(hist_pyz)["Sum[XYZ]"].sum(ax),
    label="Sum[XYZ]",
)
# plt.step(
#     x, combined(hist_pyz)["Sum[XY]Sum[Z]"].sum(ax) / n,
#     label="Sum[XY]Sum[Z] / N",
# )
# plt.step(
#     x, combined(hist_pyz)["Sum[XZ]Sum[Y]"].sum(ax) / n,
#     label="Sum[XZ]Sum[Y] / N",
# )
# plt.step(
#     x, combined(hist_pyz)["Sum[YZ]Sum[X]"].sum(ax) / n,
#     label="Sum[YZ]Sum[X] / N",
# )
# plt.step(
#     x, combined(hist_pyz)["Sum[X]Sum[Y]Sum[Z]"].sum(ax) / n ** 2,
#     label="Sum[X]Sum[Y]Sum[Z] / N ** 2",
# )
plt.axhline(0, color="k")
plt.minorticks_on()
plt.grid(True, which="both")
# plt.legend(shadow=True)
plt.gca().label_outer()

plt.tight_layout()
plt.savefig("Figures/aq035--aq036; Covariant total momentum; C2p,I3p,I2p.pdf")
plt.show()
